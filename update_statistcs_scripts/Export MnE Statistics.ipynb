# %%
import ee
import google
import pandas as pd
import csv
from google.colab import files

# %%
ee.Authenticate()

# %%
ee.Initialize(project='servir-ee')

# %%
# Define the FeatureCollection and attribute mapping Coountry
country_feature = ee.FeatureCollection('projects/servir-mekong/Cambodia-Dashboard-tool/boundaries/cambodia_country')
country_attribute = {
    'id': "ID_0",
    'name': "NAME_0",
    'output_file': "country"
}

country = {
    'feature_collection': country_feature,
    'attributes': country_attribute
}

# Define the FeatureCollection and attribute mapping Province
provinces_feature = ee.FeatureCollection('projects/servir-mekong/Cambodia-Dashboard-tool/boundaries/province')
provinces_attribute = {
    'id': "gid",
    'name': "HRName",
    'output_file': "provinces"
}

provinces = {
    'feature_collection': provinces_feature,
    'attributes': provinces_attribute
}

# Define the FeatureCollection and attribute mapping Province
districts_feature = ee.FeatureCollection('projects/servir-mekong/Cambodia-Dashboard-tool/boundaries/district')
districts_attribute = {
    'id': "DIST_CODE",
    'name': "DIST_NAME",
    'output_file': "districts"
}

districts = {
    'feature_collection': districts_feature,
    'attributes': districts_attribute
}

# Define the FeatureCollection and attribute mapping Province
protected_areas_feature = ee.FeatureCollection('projects/servir-mekong/Cambodia-Dashboard-tool/boundaries/protected_area_2023')
protected_areas_attribute = {
    'id': "PA_ID",
    'name': "PA_NAME",
    'output_file': "protected_areas"
}

protected_areas = {
    'feature_collection': protected_areas_feature,
    'attributes': protected_areas_attribute
}

# %%
landcover_image_pattern = "projects/servir-mekong/RLCMSV2/lc_cambodia_logical_v2/lc_cambodia_logical_v2_{}"

landcover_class = [
        {'name': 'built', 'number': 0, 'color': 'E600A9'},
        {'name': 'mangrove', 'number': 1, 'color': 'FFFF00'},
        {'name': 'otherPlantation', 'number': 2, 'color': 'c49963'},
        {'name': 'water', 'number': 3, 'color': '004DA8'},
        {'name': 'shrub', 'number': 4, 'color': '89CD66'},
        {'name': 'rice', 'number': 5, 'color': 'fefdbd'},
        {'name': 'cropland', 'number': 6, 'color': 'FFD37F'},
        {'name': 'grass', 'number': 7, 'color': 'D7C29E'},
        {'name': 'evergreen', 'number': 8, 'color': '267300'},
        {'name': 'deciduous', 'number': 9, 'color': '71a405'},
        {'name': 'wetland', 'number': 10, 'color': '86d8dc'},
        {'name': 'rubber', 'number': 11, 'color': 'AAFF00'},
        {'name': 'floodedForest', 'number': 12, 'color': 'b3d59f'},
        {'name': 'semi', 'number': 13, 'color': '38A800'},
        {'name': 'village', 'number': 14, 'color': 'A900E6'},
        {'name': 'others', 'number': 15, 'color': 'f0f8ff'}
    ]

other_class_landcover = "Unknown"

# %%
MOE_landcover_image_pattern = "projects/cemis-camp/assets/landcover/MOE/{}"

MOE_landcover_class = [
        {'name': 'evergreen', 'number': 1, 'color': '267300'},
        {'name': 'semi', 'number': 2, 'color': '38A800'},
        {'name': 'deciduous', 'number': 3, 'color': '70A800'},
        {'name': 'unknown_1', 'number': 4, 'color': 'A8A800'},
        {'name': 'woodshrub', 'number': 5, 'color': '89CD66'},
        {'name': 'mangrove', 'number': 6, 'color': '00A884'},
        {'name': 'unknown_2', 'number': 7, 'color': '0084A8'},
        {'name': 'rubber', 'number': 8, 'color': 'AAFF00'},
        {'name': 'flooded forest', 'number': 9, 'color': 'B4D79E'},
        {'name': 'unknown_3', 'number': 10, 'color': 'A3FF73'},
        {'name': 'unknown_4', 'number': 11, 'color': 'ABCD66'},
        {'name': 'unknown_5', 'number': 12, 'color': 'CDCD66'},
        {'name': 'other plantations', 'number': 13, 'color': 'F5F57A'},
        {'name': 'unknown_6', 'number': 14, 'color': 'A5F57A'},
        {'name': 'rice', 'number': 15, 'color': 'FFFFBE'},
        {'name': 'cropland', 'number': 16, 'color': 'FFD37F'},
        {'name': 'grassland', 'number': 17, 'color': 'D7C29E'},
        {'name': 'built-up area', 'number': 18, 'color': 'E600A9'},
        {'name': 'village', 'number': 19, 'color': 'A900E6'},
        {'name': 'unknown_7', 'number': 20, 'color': '686868'},
        {'name': 'unknown_8', 'number': 21, 'color': 'F57A7A'},
        {'name': 'water', 'number': 22, 'color': '004DA8'}
    ]

MOE_other_class_landcover = "Unknown"

# %%
forest_loss_image_pattern = "projects/servir-mekong/UMD/Loss_C02/{}"

forest_loss_class = [
        {'name': 'forest loss', 'number': 1, 'color': 'E600A9'},
    ]

other_class_forest_loss = "No Deforestation"

# %%
tcc_tch_image_pattern = ["projects/servir-mekong/UMD/TCC_C02/{}", "projects/servir-mekong/UMD/TCH_C02/{}"]

forest_cover_class = [
        {'name': 'forest cover', 'number': 1, 'color': 'E600A9'},
    ]

other_class_forest_cover = "non forest"

# %%
glad_image_pattern = "projects/glad/alert/{}final"

glad_class = [
        {'name': 'alert', 'number': 1, 'color': 'E600A9'},
    ]

other_class_glad = "no alert"

# %%
sar_image_pattern = "projects/cemis-camp/assets/sarAlert/alert_{}V4"

sar_class = [
        {'name': 'alert', 'number': 1, 'color': 'E600A9'},
    ]

other_class_sar = "no alert"

# %%
sarfdas_image_pattern = "projects/cemis-camp/assets/khForestAlert/combinedDeforestationAlertv2"

sarfdas_class = [
        {'name': 'alert', 'number': 1, 'color': 'E600A9'},
    ]

other_class_sarfdas = "no alert"

# %%
def calLandcoverArea(boundary, year, image_pattern, classStat, other_class):
    image_id = image_pattern.format(year)

    # Load the land cover image
    imageProcess = ee.Image(image_id)

    # Mapping class numbers to names
    INDEX_CLASS = {cls['number']: cls['name'] for cls in classStat}

    # Add pixel area band to the land cover image
    areaImage = ee.Image.pixelArea().addBands(imageProcess)

    # Calculate the area for each class in each province
    class_areas = areaImage.reduceRegions(
        collection=boundary['feature_collection'],
        reducer=ee.Reducer.sum().group(
            groupField=1,
            groupName='statistics_class',
        ),
        scale=30
    )

    # Retrieve the results
    data = class_areas.getInfo()['features']

    # Process and structure the data
    AreaClass = []
    for feature in data:
        id = feature['properties'][boundary['attributes']['id']]
        name = feature['properties'][boundary['attributes']['name']]
        groups = feature['properties']['groups']
        for group in groups:
            class_number = group['statistics_class']
            class_name = INDEX_CLASS.get(class_number, other_class)
            area_ha = group['sum'] / 10000  # Convert from square meters to hectares
            AreaClass.append({
                'code': id,
                'name': name,
                'year': year,
                'stat': class_name,
                'area_ha': area_ha
            })

    print(AreaClass)
    return AreaClass

# %%
def calculate_forest_cover_stats(boundary, year, image_pattern, classStat, other_class):
    tcc = image_pattern[0].format(year)
    tch = image_pattern[1].format(year)

    print(tcc, tch)

    # Load the land cover image
    imageTCC = ee.Image(tcc)
    imageTCH = ee.Image(tch)

    # Create forest cover map
    imageProcess = imageTCC.select('b1').gt(10).And(imageTCH.select('b1').gt(5))


    # Mapping class numbers to names
    INDEX_CLASS = {cls['number']: cls['name'] for cls in classStat}

    # Add pixel area band to the land cover image
    areaImage = ee.Image.pixelArea().addBands(imageProcess)

    # Calculate the area for each class in each province
    class_areas = areaImage.reduceRegions(
        collection=boundary['feature_collection'],
        reducer=ee.Reducer.sum().group(
            groupField=1,
            groupName='statistics_class',
        ),
        scale=30
    )

    # Retrieve the results
    data = class_areas.getInfo()['features']

    # Process and structure the data
    AreaClass = []
    for feature in data:
        id = feature['properties'][boundary['attributes']['id']]
        name = feature['properties'][boundary['attributes']['name']]
        groups = feature['properties']['groups']
        for group in groups:
            class_number = group['statistics_class']
            class_name = INDEX_CLASS.get(class_number, other_class)
            area_ha = group['sum'] / 10000  # Convert from square meters to hectares
            AreaClass.append({
                'code': id,
                'name': name,
                'year': year,
                'stat': class_name,
                'area_ha': area_ha
            })

    print(AreaClass)
    return AreaClass

# %%
def calculate_glad_statistics(boundary, year, image_pattern, classStat, other_class):
    def adjust_year(year):
      if year == 2023:
          year = 2022
      return year

    # Adjust the year if needed
    adjusted_year = adjust_year(year)
    image_id = image_pattern.format(adjusted_year)
    alertBand = "alertDate{}".format(year % 100)

    # Load the ImageCollection
    imageCollection = ee.ImageCollection(image_id)

    # Reduce the ImageCollection to get the maximum value of alertBand across all images
    maxImage = imageCollection.select(alertBand).reduce(ee.Reducer.max())

    # Create a binary image where the max values are greater than 0
    imageProcess = maxImage.gt(0)

    # Mapping class numbers to names
    INDEX_CLASS = {cls['number']: cls['name'] for cls in classStat}

    # Add pixel area band to the land cover image
    areaImage = ee.Image.pixelArea().addBands(imageProcess)

    # Calculate the area for each class in each province
    class_areas = areaImage.reduceRegions(
        collection=boundary['feature_collection'],
        reducer=ee.Reducer.sum().group(
            groupField=1,
            groupName='statistics_class',
        ),
        scale=30
    )

    # Retrieve the results
    data = class_areas.getInfo()['features']

    # Process and structure the data
    AreaClass = []
    for feature in data:
        id = feature['properties'][boundary['attributes']['id']]
        name = feature['properties'][boundary['attributes']['name']]
        groups = feature['properties']['groups']
        for group in groups:
            class_number = group['statistics_class']
            class_name = INDEX_CLASS.get(class_number, other_class)
            area_ha = group['sum'] / 10000  # Convert from square meters to hectares
            AreaClass.append({
                'code': id,
                'name': name,
                'year': year,
                'stat': class_name,
                'area_ha': area_ha
            })

    print(AreaClass)
    return AreaClass

# %%
def calculate_sar_statistics(boundary, year, image_pattern, classStat, other_class):

    # Load the land cover image
    image_id = image_pattern.format(year)

    # Load the ImageCollection
    imageLoad = ee.Image(image_id)

    # Select the 'landclass' band
    landclassImage = imageLoad.select('landclass')

    # Create a binary image where the values of 'landclass' band are greater than 0
    imageProcess = landclassImage.gt(0)

    # Mapping class numbers to names
    INDEX_CLASS = {cls['number']: cls['name'] for cls in classStat}

    # Add pixel area band to the land cover image
    areaImage = ee.Image.pixelArea().addBands(imageProcess)

    # Calculate the area for each class in each province
    class_areas = areaImage.reduceRegions(
        collection=boundary['feature_collection'],
        reducer=ee.Reducer.sum().group(
            groupField=1,
            groupName='statistics_class',
        ),
        scale=10
    )

    # Retrieve the results
    data = class_areas.getInfo()['features']

    # Process and structure the data
    AreaClass = []
    for feature in data:
        id = feature['properties'][boundary['attributes']['id']]
        name = feature['properties'][boundary['attributes']['name']]
        groups = feature['properties']['groups']
        for group in groups:
            class_number = group['statistics_class']
            class_name = INDEX_CLASS.get(class_number, other_class)
            area_ha = group['sum'] / 10000  # Convert from square meters to hectares
            AreaClass.append({
                'code': id,
                'name': name,
                'year': year,
                'stat': class_name,
                'area_ha': area_ha
            })

    print(AreaClass)
    return AreaClass

# %%
def calSarfdasAlert(boundary, year, image_collection_id, classStat, other_class):
    # Initialize Earth Engine
    ee.Initialize()

    # Define the ImageCollection and filter by year
    imageCollection = ee.ImageCollection(image_collection_id).filterDate(f'{year}-01-01', f'{year}-12-31')

    # Select the 'combinedAlerts' band
    combinedAlerts = imageCollection.select('combinedAlerts')

    # Combine images by taking the max value for the year
    maxImage = combinedAlerts.max()

    # Convert to binary image where pixel values > 0 are set to 1
    binaryImage = maxImage.gt(0)

    # Add pixel area band to the binary image
    areaImage = ee.Image.pixelArea().addBands(binaryImage.rename('class'))

    # Mapping class numbers to names
    INDEX_CLASS = {cls['number']: cls['name'] for cls in classStat}

    # Calculate the area for each class in each province
    class_areas = areaImage.reduceRegions(
        collection=boundary['feature_collection'],
        reducer=ee.Reducer.sum().group(
            groupField=1,
            groupName='statistics_class',
        ),
        scale=10
    )

    # Retrieve the results
    data = class_areas.getInfo()['features']

    # Process and structure the data
    AreaClass = []
    for feature in data:
        id = feature['properties'][boundary['attributes']['id']]
        name = feature['properties'][boundary['attributes']['name']]
        groups = feature['properties']['groups']
        for group in groups:
            class_number = group['statistics_class']
            class_name = INDEX_CLASS.get(class_number, other_class)
            area_ha = group['sum'] / 10000  # Convert from square meters to hectares
            AreaClass.append({
                'code': id,
                'name': name,
                'year': year,
                'stat': class_name,
                'area_ha': area_ha
            })

    print(AreaClass)
    return AreaClass

# %%
def calculate_forest_fires(boundary_fc, year, start_date, end_date, unique_id):
    # Load FIRMS ImageCollection
    firms_ic = ee.ImageCollection('FIRMS').filterDate(start_date, end_date)

    def process_boundary(id):
        roi = boundary_fc.filter(ee.Filter.eq(unique_id, id))

        fire = firms_ic.select('T21').max().toInt16().clip(roi.geometry())

        # Confidence more than 90%
        mask_conf = firms_ic.select('confidence').mean().gt(90).toInt16()
        fire = fire.updateMask(mask_conf)

        # Binary image
        binary_image = fire.neq(0).rename(['binary']).multiply(1).toInt16().selfMask()

        # Reduce to vectors
        vectors = binary_image.addBands(binary_image).reduceToVectors(
            crs=binary_image.select('binary').projection(),
            scale=1000,
            geometryType='polygon',
            eightConnected=False,
            labelProperty='zone',
            reducer=ee.Reducer.sum(),
            maxPixels=1e15,
            bestEffort=True
        ).filter(ee.Filter.gt('sum', 1))

        def calculate_area(feature):
            area = feature.geometry().area(10)
            return feature.set('area', area)

        all_areas = vectors.map(calculate_area)
        total_area = ee.Number(all_areas.aggregate_sum('area')).divide(10000)  # Convert to hectares
        number_of_fires = vectors.size()

        roi_feature = ee.Feature(roi.first()).set({
            'areaHect': total_area,
            'numberFire': number_of_fires,
            'year': year
        })

        return roi_feature

    ids = boundary_fc.aggregate_array(unique_id).getInfo()
    results = [process_boundary(id) for id in ids]

    return ee.FeatureCollection(results)

# %%
def collect_and_process_data(boundary, indicator, start_year, end_year, image_pattern, classStat, other_class):
    # Assuming calDeforestationArea is defined elsewhere

    # Function to iterate over years and collect data
    def collectData(boundary, indicator, start_year, end_year):
        all_data = []
        for year in range(start_year, end_year + 1):  # end_year is inclusive
            # Conditional execution based on the indicator
            if indicator == 'landcover':
                yearly_data = calLandcoverArea(boundary, year, image_pattern, classStat, other_class)
            elif indicator == 'forest_loss':
                yearly_data = calLandcoverArea(boundary, year, image_pattern, classStat, other_class)
            elif indicator == 'forest_cover':
                yearly_data = calculate_forest_cover_stats(boundary, year, image_pattern, classStat, other_class)
            elif indicator == 'glad_alert':
                yearly_data = calculate_glad_statistics(boundary, year, image_pattern, classStat, other_class)
            elif indicator == 'sar_alert':
                yearly_data = calculate_sar_statistics(boundary, year, image_pattern, classStat, other_class)
            elif indicator == 'sarfdas_alert':
                yearly_data = calSarfdasAlert(boundary, year, image_pattern, classStat, other_class)
            else:
                raise ValueError(f"Unknown indicator: {indicator}")

            all_data.extend(yearly_data)
        return all_data

    # Collect data within the given year range
    data_list = collectData(boundary, indicator, start_year, end_year)

    # Convert the list of dictionaries to a DataFrame
    data = pd.DataFrame(data_list)

    # Identify unique combinations of code/name, year, and stat
    unique_combinations = data[['code', 'name', 'year', 'stat']].drop_duplicates()

    # Generate a complete set of combinations for these columns
    complete_combinations = pd.MultiIndex.from_product(
        [data['code'].unique(), data['year'].unique(), data['stat'].unique()],
        names=['code', 'year', 'stat']
    ).to_frame(index=False)

    # Map code to name to ensure consistency
    code_name_map = data[['code', 'name']].drop_duplicates().set_index('code')['name']
    complete_combinations['name'] = complete_combinations['code'].map(code_name_map)

    # Identify the missing combinations by merging
    missing_combinations = pd.merge(
        complete_combinations,
        data,
        on=['code', 'name', 'year', 'stat'],
        how='left'
    )

    # Filter out the missing entries and set area_ha to 0
    missing_combinations = missing_combinations[missing_combinations['area_ha'].isnull()]
    missing_combinations['area_ha'] = 0

    # Combine the original data with the missing combinations
    filled_data = pd.concat([data, missing_combinations[['code', 'name', 'year', 'stat', 'area_ha']]])

    output_file = f"{indicator}_{boundary['attributes']['output_file']}.csv"

    # Save the filled data to a new CSV file
    filled_data.to_csv(output_file, index=False)

    print(f"Data written to {output_file}")

    # Download the file
    files.download(output_file)

# %%
def run_zonal_statistics_calculations(boundaries, indicator, start_year, end_year, image_pattern, classStat, other_class):
      for boundary in boundaries:
              collect_and_process_data(boundary, indicator, start_year, end_year, image_pattern, classStat, other_class)

# %%
boundaries = [country, provinces, districts, protected_areas]

# run_zonal_statistics_calculations(boundaries, "landcover", 2000, 2023, landcover_image_pattern, landcover_class, other_class_landcover)

# run_zonal_statistics_calculations(boundaries, "forest_loss", 2000, 2023, forest_loss_image_pattern, forest_loss_class, other_class_forest_loss)

# run_zonal_statistics_calculations(boundaries, "forest_cover", 2000, 2023, tcc_tch_image_pattern, forest_cover_class, other_class_forest_cover)

# run_zonal_statistics_calculations(boundaries, "glad_alert", 2018, 2023, glad_image_pattern, glad_class, other_class_glad)

# run_zonal_statistics_calculations(boundaries, "sar_alert", 2018, 2023, sar_image_pattern, sar_class, other_class_sar)

run_zonal_statistics_calculations(boundaries, "sarfdas_alert", 2021, 2024, sarfdas_image_pattern, sarfdas_class, other_class_sarfdas)
# Out:
# [{'code': 40, 'name': 'Cambodia', 'year': 2021, 'stat': 'alert', 'area_ha': 39653.528618941724}]
# [{'code': 40, 'name': 'Cambodia', 'year': 2022, 'stat': 'alert', 'area_ha': 26030.096114927434}]
# [{'code': 40, 'name': 'Cambodia', 'year': 2023, 'stat': 'alert', 'area_ha': 23010.15768504061}]
# [{'code': 40, 'name': 'Cambodia', 'year': 2024, 'stat': 'alert', 'area_ha': 25746.379696691834}]
# Data written to sarfdas_alert_country.csv
# [{'code': 1, 'name': 'Banteay Meanchey', 'year': 2021, 'stat': 'alert', 'area_ha': 51.90795623223996}, {'code': 2, 'name': 'Battambang', 'year': 2021, 'stat': 'alert', 'area_ha': 456.05989312678315}, {'code': 5, 'name': 'Kampong Chhnang', 'year': 2021, 'stat': 'alert', 'area_ha': 193.2085904308663}, {'code': 6, 'name': 'Kampong Speu', 'year': 2021, 'stat': 'alert', 'area_ha': 185.01826265481688}, {'code': 4, 'name': 'Kampong Cham', 'year': 2021, 'stat': 'alert', 'area_ha': 615.8285582756821}, {'code': 7, 'name': 'Kampong Thom', 'year': 2021, 'stat': 'alert', 'area_ha': 7665.056875909102}, {'code': 3, 'name': 'Kampot', 'year': 2021, 'stat': 'alert', 'area_ha': 500.30204134528964}, {'code': 8, 'name': 'Kandal', 'year': 2021, 'stat': 'alert', 'area_ha': 43.75051944503784}, {'code': 9, 'name': 'Koh Kong', 'year': 2021, 'stat': 'alert', 'area_ha': 2766.487100560207}, {'code': 11, 'name': 'Kratie', 'year': 2021, 'stat': 'alert', 'area_ha': 5258.032953195648}, {'code': 14, 'name': 'Mondul Kiri', 'year': 2021, 'stat': 'alert', 'area_ha': 2301.093032573314}, {'code': 18, 'name': 'Preah Vihear', 'year': 2021, 'stat': 'alert', 'area_ha': 4126.762833115562}, {'code': 19, 'name': 'Prey Veng', 'year': 2021, 'stat': 'alert', 'area_ha': 1.2487347224665624}, {'code': 17
takeo', 'year': 2024, 'stat': 'alert', 'area_ha': 3.57465991897583}, {'code': 15, 'name': 'Oddar Meanchey', 'year': 2024, 'stat': 'alert', 'area_ha': 559.1889629529646}, {'code': 10, 'name': 'Kep', 'year': 2024, 'stat': 'alert', 'area_ha': 1.8760559715270997}, {'code': 12, 'name': 'Pailin', 'year': 2024, 'stat': 'alert', 'area_ha': 17.214472975523705}]
# Data written to sarfdas_alert_provinces.csv
# [{'code': '2301', 'name': "Damnak Chang'aeur", 'year': 2021, 'stat': 'alert', 'area_ha': 11.129118057852352}, {'code': '2302', 'name': 'Krong Kaeb', 'year': 2021, 'stat': 'alert', 'area_ha': 2.6083413581848145}, {'code': '2101', 'name': 'Angkor Borei', 'year': 2021, 'stat': 'alert', 'area_ha': 0.1073271583557129}, {'code': '2104', 'name': 'Kiri Vong', 'year': 2021, 'stat': 'alert', 'area_ha': 16.201610005187987}, {'code': '2109', 'name': 'Tram Kak', 'year': 2021, 'stat': 'alert', 'area_ha': 0.06826756286621094}, {'code': '2110', 'name': 'Treang', 'year': 2021, 'stat': 'alert', 'area_ha': 10.041263109588623}, {'code': '0701', 'name': 'Angkor Chey', 'year': 2021, 'stat': 'alert', 'area_ha': 0.8981350685119629}, {'code': '0702', 'name': 'Banteay Meas', 'year': 2021, 'stat': 'alert', 'area_ha': 0.08786880111694335}, {'code': '0703', 'name': 'Chhuk', 'year': 2021, 'stat': 'alert', 'area_ha': 303.8763458714863}, {'code': '0704', 'name': 'Chum Kiri', 'year': 2021, 'stat': 'alert', 'area_ha': 4.321889323425293}, {'code': '0705', 'name': 'Dang Tong', 'year': 2021, 'stat': 'alert', 'area_ha': 0.0878984504699707}, {'code': '0706', 'name': 'Kampong Trach', 'year': 2021, 'stat': 'alert', 'area_ha': 2.003242901874617}, {'code': '0707', 'name': 'Tuek Chhou', 'year': 2021, 'stat': 'alert', 'area_ha': 188.6230990668712}, {'code': '0708', 'name': 'Krong Kampot', 'year': 2021, 'stat': 'alert', 'area_ha': 1.0743970710754394}, {'code': '0803', 'name': 'Khsach Kandal', 'year': 2021, 'stat': 'alert', 'area_ha': 5.061907990264893}, {'code': '0804', 'name': 'Kaoh Thum', 'year': 2021, 'stat': 'alert', 'area_ha': 5.011166751098632}, {'code': '0805', 'name': 'Leuk Daek', 'year': 2021, 'stat': 'alert', 'area_ha': 5.65978044312421}, {'code': '0806', 'name': 'Lvea Aem', 'year': 2021, 'stat': 'alert', 'area_ha': 2.356514533996582}, {'code': '0810', 'name': "S'ang", 'year': 2021, 'stat': 'alert', 'area_ha': 8.149233767155668}, {'code': '0802', 'name': 'Kien Svay', 'year': 2021, 'stat': 'alert', 'area_ha': 0.45782383880615235}, {'code': '0807', 'name': 'Mukh kampul', 'year': 2021, 'stat': 'alert', 'area_ha': 3.541896969604492}, {'code': '0801', 'name': 'Kandal Stueng', 'year': 2021, 'stat': 'alert', 'area_ha': 13.512156934356689}, {'code': '1001', 'name': 'Chhloung', 'year': 2021, 'stat': 'alert', 'area_ha': 148.74352945528815}, {'code': '1002', 'name': 'Krong Kracheh', 'year': 2021, 'stat': 'alert', 'area_ha': 0.009704380798339844}, {'code': '1003', 'name': 'Preaek Prasab', 'year': 2021, 'stat': 'alert', 'area_ha': 436.80928629335284}, {'code': '1004', 'name': 'Sambour', 'year': 2021, 'stat': 'alert', 'area_ha': 3947.402059167083}, {'code': '1005', 'name': 'Snuol', 'year': 2021, 'stat': 'alert', 'area_ha': 565.0781805214617}, {'code': '1006', 'name': 'Chitr Borie', 'year': 2021, 'stat': 'alert', 'area_ha': 158.4984599853037}, {'code': '2401', 'name': 'Krong Pailin', 'year': 2021, 'stat': 'alert', 'area_ha': 20.573505519777186}, {'code': '2402', 'name': 'Sala Krau', 'year': 2021, 'stat': 'alert', 'area_ha': 23.21611757451376}, {'code': '1501', 'name': 'Bakan', 'year': 2021, 'stat': 'alert', 'area_ha': 8.873676823625752}, {'code': '1502', 'name': 'Kandieng', 'year': 2021, 'stat': 'alert', 'area_ha': 2.482364658355713}, {'code': '1503', 'name': 'Krakor', 'year': 2021, 'stat': 'alert', 'area_ha': 86.05318831987569}, {'code': '1504', 'name': 'Phnum Kravanh', 'year': 2021, 'stat': 'alert', 'area_ha': 504.8661879349742}, {'code': '1505', 'name': 'Krong Pursat', 'year': 2021, 'stat': 'alert', 'area_ha': 16.887998786926268}, {'code': '1506', 'name': 'Veal Veaeng', 'year': 2021, 'stat': 'alert', 'area_ha': 984.2708332497302}, {'code': '0901', 'name': 'Botum Sakor', 'year': 2021, 'stat': 'alert', 'area_ha': 564.7384919891955}, {'code': '0902', 'name': 'Kiri Sakor', 'year': 2021, 'stat': 'alert', 'area_ha': 203.50407219977285}, {'code': '0903', 'name': 'Koh Kong', 'year': 2021, 'stat': 'alert', 'area_ha': 545.692424746758}, {'code': '0904', 'name': 'Krong Khemarak Phoumi ...
# [{'code': '2301', 'name': "Damnak Chang'aeur", 'year': 2022, 'stat': 'alert', 'area_ha': 11.176140493998808}, {'code': '2302', 'name': 'Krong Kaeb', 'year': 2022, 'stat': 'alert', 'area_ha': 6.840434891474107}, {'code': '2101', 'name': 'Angkor Borei', 'year': 2022, 'stat': 'alert', 'area_ha': 0.06829995956420898}, {'code': '2102', 'name': 'Bati', 'year': 2022, 'stat': 'alert', 'area_ha': 1.023211083984375}, {'code': '2104', 'name': 'Kiri Vong', 'year': 2022, 'stat': 'alert', 'area_ha': 3.593802101135254}, {'code': '2109', 'name': 'Tram Kak', 'year': 2022, 'stat': 'alert', 'area_ha': 0.30233526077270506}, {'code': '2110', 'name': 'Treang', 'year': 2022, 'stat': 'alert', 'area_ha': 1.7760530181884766}, {'code': '0701', 'name': 'Angkor Chey', 'year': 2022, 'stat': 'alert', 'area_ha': 0.9372045478820801}, {'code': '0702', 'name': 'Banteay Meas', 'year': 2022, 'stat': 'alert', 'area_ha': 0.3125230712890625}, {'code': '0703', 'name': 'Chhuk', 'year': 2022, 'stat': 'alert', 'area_ha': 184.7289337425232}, {'code': '0704', 'name': 'Chum Kiri', 'year': 2022, 'stat': 'alert', 'area_ha': 3.1218390396118165}, {'code': '0705', 'name': 'Dang Tong', 'year': 2022, 'stat': 'alert', 'area_ha': 0.009762911224365234}, {'code': '0706', 'name': 'Kampong Trach', 'year': 2022, 'stat': 'alert', 'area_ha': 1.963610195159912}, {'code': '0707', 'name': 'Tuek Chhou', 'year': 2022, 'stat': 'alert', 'area_ha': 59.272807655334475}, {'code': '0708', 'name': 'Krong Kampot', 'year': 2022, 'stat': 'alert', 'area_ha': 0.6056553962707519}, {'code': '0803', 'name': 'Khsach Kandal', 'year': 2022, 'stat': 'alert', 'area_ha': 0.32122298431396484}, {'code': '0804', 'name': 'Kaoh Thum', 'year': 2022, 'stat': 'alert', 'area_ha': 5.6349158943176265}, {'code': '0805', 'name': 'Leuk Daek', 'year': 2022, 'stat': 'alert', 'area_ha': 12.241187293243408}, {'code': '0806', 'name': 'Lvea Aem', 'year': 2022, 'stat': 'alert', 'area_ha': 4.362201933288574}, {'code': '0810', 'name': "S'ang", 'year': 2022, 'stat': 'alert', 'area_ha': 10.505800991058349}, {'code': '0809', 'name': 'Popnhea Lueu', 'year': 2022, 'stat': 'alert', 'area_ha': 0.36974473266601565}, {'code': '0802', 'name': 'Kien Svay', 'year': 2022, 'stat': 'alert', 'area_ha': 0.7111738494873047}, {'code': '0807', 'name': 'Mukh kampul', 'year': 2022, 'stat': 'alert', 'area_ha': 2.0628606033325196}, {'code': '0801', 'name': 'Kandal Stueng', 'year': 2022, 'stat': 'alert', 'area_ha': 0.3215184288024902}, {'code': '1001', 'name': 'Chhloung', 'year': 2022, 'stat': 'alert', 'area_ha': 106.66648800739662}, {'code': '1003', 'name': 'Preaek Prasab', 'year': 2022, 'stat': 'alert', 'area_ha': 222.25261563463994}, {'code': '1004', 'name': 'Sambour', 'year': 2022, 'stat': 'alert', 'area_ha': 2606.02476485638}, {'code': '1005', 'name': 'Snuol', 'year': 2022, 'stat': 'alert', 'area_ha': 510.5036007148384}, {'code': '1006', 'name': 'Chitr Borie', 'year': 2022, 'stat': 'alert', 'area_ha': 166.8002989843301}, {'code': '2401', 'name': 'Krong Pailin', 'year': 2022, 'stat': 'alert', 'area_ha': 11.551385866546632}, {'code': '2402', 'name': 'Sala Krau', 'year': 2022, 'stat': 'alert', 'area_ha': 10.47286366192986}, {'code': '1501', 'name': 'Bakan', 'year': 2022, 'stat': 'alert', 'area_ha': 31.18502558670044}, {'code': '1502', 'name': 'Kandieng', 'year': 2022, 'stat': 'alert', 'area_ha': 10.266129511260987}, {'code': '1503', 'name': 'Krakor', 'year': 2022, 'stat': 'alert', 'area_ha': 71.22953767675662}, {'code': '1504', 'name': 'Phnum Kravanh', 'year': 2022, 'stat': 'alert', 'area_ha': 165.6347017784807}, {'code': '1505', 'name': 'Krong Pursat', 'year': 2022, 'stat': 'alert', 'area_ha': 1.2714074005126954}, {'code': '1506', 'name': 'Veal Veaeng', 'year': 2022, 'stat': 'alert', 'area_ha': 729.6836054104015}, {'code': '0901', 'name': 'Botum Sakor', 'year': 2022, 'stat': 'alert', 'area_ha': 1144.946055254032}, {'code': '0902', 'name': 'Kiri Sakor', 'year': 2022, 'stat': 'alert', 'area_ha': 49.457024184417726}, {'code': '0903', 'name': 'Koh Kong', 'year': ...
# [{'code': '2301', 'name': "Damnak Chang'aeur", 'year': 2023, 'stat': 'alert', 'area_ha': 3.1560362281799317}, {'code': '2302', 'name': 'Krong Kaeb', 'year': 2023, 'stat': 'alert', 'area_ha': 3.2435650146484374}, {'code': '2102', 'name': 'Bati', 'year': 2023, 'stat': 'alert', 'area_ha': 0.3800477195739746}, {'code': '2104', 'name': 'Kiri Vong', 'year': 2023, 'stat': 'alert', 'area_ha': 1.3575725044250488}, {'code': '2109', 'name': 'Tram Kak', 'year': 2023, 'stat': 'alert', 'area_ha': 0.3803533729553223}, {'code': '2110', 'name': 'Treang', 'year': 2023, 'stat': 'alert', 'area_ha': 0.0878271842956543}, {'code': '0701', 'name': 'Angkor Chey', 'year': 2023, 'stat': 'alert', 'area_ha': 0.47836224670410155}, {'code': '0702', 'name': 'Banteay Meas', 'year': 2023, 'stat': 'alert', 'area_ha': 0.2441122573852539}, {'code': '0703', 'name': 'Chhuk', 'year': 2023, 'stat': 'alert', 'area_ha': 14.470459005189783}, {'code': '0704', 'name': 'Chum Kiri', 'year': 2023, 'stat': 'alert', 'area_ha': 2.4743404490452185}, {'code': '0705', 'name': 'Dang Tong', 'year': 2023, 'stat': 'alert', 'area_ha': 0.3514959228515625}, {'code': '0706', 'name': 'Kampong Trach', 'year': 2023, 'stat': 'alert', 'area_ha': 1.6197321912578506}, {'code': '0707', 'name': 'Tuek Chhou', 'year': 2023, 'stat': 'alert', 'area_ha': 109.12714593170166}, {'code': '0708', 'name': 'Krong Kampot', 'year': 2023, 'stat': 'alert', 'area_ha': 0.12699374313354492}, {'code': '0804', 'name': 'Kaoh Thum', 'year': 2023, 'stat': 'alert', 'area_ha': 4.864833620452881}, {'code': '0805', 'name': 'Leuk Daek', 'year': 2023, 'stat': 'alert', 'area_ha': 8.996021266937255}, {'code': '0806', 'name': 'Lvea Aem', 'year': 2023, 'stat': 'alert', 'area_ha': 2.1327902252197264}, {'code': '0810', 'name': "S'ang", 'year': 2023, 'stat': 'alert', 'area_ha': 9.891859259033204}, {'code': '0809', 'name': 'Popnhea Lueu', 'year': 2023, 'stat': 'alert', 'area_ha': 0.09728209838867187}, {'code': '0802', 'name': 'Kien Svay', 'year': 2023, 'stat': 'alert', 'area_ha': 1.6076353759765625}, {'code': '0807', 'name': 'Mukh kampul', 'year': 2023, 'stat': 'alert', 'area_ha': 0.4378455131530762}, {'code': '1001', 'name': 'Chhloung', 'year': 2023, 'stat': 'alert', 'area_ha': 43.07702508316639}, {'code': '1002', 'name': 'Krong Kracheh', 'year': 2023, 'stat': 'alert', 'area_ha': 0.20383173446655273}, {'code': '1003', 'name': 'Preaek Prasab', 'year': 2023, 'stat': 'alert', 'area_ha': 51.672289517211915}, {'code': '1004', 'name': 'Sambour', 'year': 2023, 'stat': 'alert', 'area_ha': 1104.3750292642687}, {'code': '1005', 'name': 'Snuol', 'year': 2023, 'stat': 'alert', 'area_ha': 139.50837050327675}, {'code': '1006', 'name': 'Chitr Borie', 'year': 2023, 'stat': 'alert', 'area_ha': 24.429493154637957}, {'code': '2401', 'name': 'Krong Pailin', 'year': 2023, 'stat': 'alert', 'area_ha': 7.559501226043701}, {'code': '2402', 'name': 'Sala Krau', 'year': 2023, 'stat': 'alert', 'area_ha': 14.931810314082727}, {'code': '1501', 'name': 'Bakan', 'year': 2023, 'stat': 'alert', 'area_ha': 55.55458414843092}, {'code': '1502', 'name': 'Kandieng', 'year': 2023, 'stat': 'alert', 'area_ha': 16.86778362045288}, {'code': '1503', 'name': 'Krakor', 'year': 2023, 'stat': 'alert', 'area_ha': 14.391302034759521}, {'code': '1504', 'name': 'Phnum Kravanh', 'year': 2023, 'stat': 'alert', 'area_ha': 203.07216991730036}, {'code': '1505', 'name': 'Krong Pursat', 'year': 2023, 'stat': 'alert', 'area_ha': 1.9313563102722169}, {'code': '1506', 'name': 'Veal Veaeng', 'year': 2023, 'stat': 'alert', 'area_ha': 1642.8046221834998}, {'code': '0901', 'name': 'Botum Sakor', 'year': 2023, 'stat': 'alert', 'area_ha': 2350.249304434318}, {'code': '0902', 'name': 'Kiri Sakor', 'year': 2023, 'stat': 'alert', 'area_ha': 112.12235797327976}, {'code': '0903', 'name': 'Koh Kong', 'year': 2023, 'stat': 'alert', 'area_ha': 365.6683981154049}, {'code': '0904', 'name': 'Krong Khemarak Phoumin', 'year': 2023, 'stat': 'alert', 'area_ha': 11.721469416046142}, {'code': '0905', 'name': 'Mondol S ...
# [{'code': '2301', 'name': "Damnak Chang'aeur", 'year': 2024, 'stat': 'alert', 'area_ha': 1.4461268867492676}, {'code': '2302', 'name': 'Krong Kaeb', 'year': 2024, 'stat': 'alert', 'area_ha': 0.42992908477783204}, {'code': '2101', 'name': 'Angkor Borei', 'year': 2024, 'stat': 'alert', 'area_ha': 0.10730838928222657}, {'code': '2104', 'name': 'Kiri Vong', 'year': 2024, 'stat': 'alert', 'area_ha': 3.3502839942932128}, {'code': '2109', 'name': 'Tram Kak', 'year': 2024, 'stat': 'alert', 'area_ha': 0.11706753540039062}, {'code': '0701', 'name': 'Angkor Chey', 'year': 2024, 'stat': 'alert', 'area_ha': 0.12690673065185548}, {'code': '0703', 'name': 'Chhuk', 'year': 2024, 'stat': 'alert', 'area_ha': 110.51054885253906}, {'code': '0704', 'name': 'Chum Kiri', 'year': 2024, 'stat': 'alert', 'area_ha': 2.770806122589111}, {'code': '0705', 'name': 'Dang Tong', 'year': 2024, 'stat': 'alert', 'area_ha': 0.18554298934936522}, {'code': '0706', 'name': 'Kampong Trach', 'year': 2024,
': 'BOENG TONLE CHHMAR', 'year': 2022, 'stat': 'alert', 'area_ha': 0.6979697486877442}, {'code': 28, 'name': 'KOH KAPI', 'year': 2022, 'stat': 'alert', 'area_ha': 77.78224464328243}, {'code': 59, 'name': 'PREK TOAL', 'year': 2022, 'stat': 'alert', 'area_ha': 1.0351916303477566}, {'code': 60, 'name': 'STUNG TRENG', 'year': 2022, 'stat': 'alert', 'area_ha': 3.5133613836849436}, {'code': 65, 'name': 'STUNG SEN', 'year': 2022, 'stat': 'alert', 'area_ha': 4.361356161199832}, {'code': 4, 'name': 'PHNOM TNOUT-PHNOM POK', 'year': 2022, 'stat': 'alert', 'area_ha': 51.921327128023634}, {'code': 6, 'name': 'PREAEK PRASAP', 'year': 2022, 'stat': 'alert', 'area_ha': 22.13391983372707}, {'code': 7, 'name': 'PREY LANG', 'year': 2022, 'stat': 'alert', 'area_ha': 2275.0967966305634}, {'code': 10, 'name': 'SAMBOR', 'year': 20 ...
# [{'code': 1, 'name': 'PREAH SIHANOUK REAM', 'year': 2023, 'stat': 'alert', 'area_ha': 121.40615845662434}, {'code': 30, 'name': 'KOH RONG', 'year': 2023, 'stat': 'alert', 'area_ha': 39.89683347244263}, {'code': 3, 'name': 'PHNOM NEANG KONGREY-PHNOM TOUK MEAS', 'year': 2023, 'stat': 'alert', 'area_ha': 0.5534440628051758}, {'code': 16, 'name': 'BOENG KARDER', 'year': 2023, 'stat': 'alert', 'area_ha': 1.068570369720459}, {'code': 23, 'name': 'DONG PENG', 'year': 2023, 'stat': 'alert', 'area_ha': 229.77162849264704}, {'code': 25, 'name': 'KBAL CHHAY', 'year': 2023, 'stat': 'alert', 'area_ha': 15.7034406706537}, {'code': 54, 'name': 'PONHEA KREK', 'year': 2023, 'stat': 'alert', 'area_ha': 0.037701224233589924}, {'code': 61, 'name': 'SAMLAUT', 'year': 2023, 'stat': 'alert', 'area_ha': 7.787772145185284}, {'code': 68, 'name': 'TONLE SAP', 'year': 2023, 'stat': 'alert', 'area_ha': 103.81878000768624}, {'code': 70, 'name': 'TUOL BOS PHNIAV', 'year': 2023, 'stat': 'alert', 'area_ha': 0.5898433997808719}, {'code': 26, 'name': 'KEP', 'year': 2023, 'stat': 'alert', 'area_ha': 1.0943175727844239}, {'code': 31, 'name': 'KRAVANH', 'year': 2023, 'stat': 'alert', 'area_ha': 1938.8754471632835}, {'code': 35, 'name': 'O YA DAW', 'year': 2023, 'stat': 'alert', 'area_ha': 80.15414879693125}, {'code': 36, 'name': 'BOTUM SAKOR', 'year': 2023, 'stat': 'alert', 'area_ha': 2518.6504100662296}, {'code': 55, 'name': 'PREAH JAYAVARMAN NORDOM PHNOM KULEN', 'year': 2023, 'stat': 'alert', 'area_ha': 28.045816248438218}, {'code': 56, 'name': 'PREAH MONIVONG BOKOR', 'year': 2023, 'stat': 'alert', 'area_ha': 217.44276102472642}, {'code': 57, 'name': 'PREAH SURAMRITH KOSSAMAK KIRIROM', 'year': 2023, 'stat': 'alert', 'area_ha': 1.9490238655090333}, {'code': 71, 'name': 'VEUN SAI-SIEM PANG', 'year': 2023, 'stat': 'alert', 'area_ha': 1291.326272308269}, {'code': 72, 'name': 'VIRACHEY', 'year': 2023, 'stat': 'alert', 'area_ha': 453.4961721437671}, {'code': 24, 'name': 'GIRI YUNG', 'year': 2023, 'stat': 'alert', 'area_ha': 0.5231811195373535}, {'code': 43, 'name': 'PHNOM PREAH-PHNOM VENG', 'year': 2023, 'stat': 'alert', 'area_ha': 0.7717661499023437}, {'code': 45, 'name': 'PHNOM PREAH NET PREAH', 'year': 2023, 'stat': 'alert', 'area_ha': 0.740657943650788}, {'code': 49, 'name': 'PHNOM TBAENG', 'year': 2023, 'stat': 'alert', 'area_ha': 8.442644206483129}, {'code': 5, 'name': 'PRASAT BAKAN', 'year': 2023, 'stat': 'alert', 'area_ha': 0.0002654468252144608}, {'code': 12, 'name': 'ANG TRAPEANG THMOR SARUS CRANE', 'year': 2023, 'stat': 'alert', 'area_ha': 0.9745449317932129}, {'code': 13, 'name': 'ANGKOR', 'year': 2023, 'stat': 'alert', 'area_ha': 0.9763793533325196}, {'code': 15, 'name': 'BANTEAY CHMAR', 'year': 2023, 'stat': 'alert', 'area_ha': 1.1087776812833898}, {'code': 34, 'name': 'TOMNEAP KANG CHEUNG TONLE SAP', 'year': 2023, 'stat': 'alert', 'area_ha': 4.666942837952258}, {'code': 58, 'name': 'PREAH VIHEAR', 'year': 2023, 'stat': 'alert', 'area_ha': 27.605580227945367}, {'code': 66, 'name': 'STUNG TRENG', 'year': 2023, 'stat': 'alert', 'area_ha': 35.52312321909886}, {'code': 73, 'name': 'BAKAN', 'year': 2023, 'stat': 'alert', 'area_ha': 24.961942067718507}, {'code': 19, 'name': 'BOENG TONLE CHHMAR', 'year': 2023, 'stat': 'alert', 'area_ha': 0.7949098731994629}, {'code': 28, 'name': 'KOH KAPI', 'year': 2023, 'stat': 'alert', 'area_ha': 44.16467273483276}, {'code': 59, 'name': 'PREK TOAL', 'year': 2023, 'stat': 'alert', 'area_ha': 0.4767581415423225}, {'code': 60, 'name': 'STUNG TRENG', 'year': 2023, 'stat': 'alert', 'area_ha': 0.9752924629211426}, {'code': 65, 'name': 'STUNG SEN', 'year': 2023, 'stat': 'alert', 'area_ha': 3.9588601885328107}, {'code': 4, 'name': 'PHNOM TNOUT-PHNOM POK', 'year': 2023, 'stat': 'alert', 'area_ha': 69.94711392801024}, {'code': 6, 'name': 'PREAEK PRASAP', 'year': 2023, 'stat': 'alert', 'area_ha': 2.744617993927002}, {'code': 7, 'name': 'PREY LANG', 'year': 2023, 'stat': 'alert', 'area_ha': 2676.6661792952445}, {'code': 10, 'name': 'SAMB ...
# WARNING:googleapiclient.http:Sleeping 0.80 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1/projects
': 'alert', 'area_ha': 2.1400070556640625}, {'code': 20, 'name': 'BOENG YAK AOM YAK KARA', 'year': 2024, 'stat': 'alert', 'area_ha': 0.3188949203491211}, {'code': 34, 'name': 'TOMNEAP KANG CHEUNG TONLE SAP', 'year': 2024, 'stat': 'alert', 'area_ha': 8.329938334676704}, {'code': 58, 'name': 'PREAH VIHEAR', 'year': 2024, 'stat': 'alert', 'area_ha': 65.13868658604042}, {'code': 66, 'name': 'STUNG TRENG', 'year': 2024, 'stat': 'alert', 'area_ha': 88.3015236786158}, {'code': 73, 'name': 'BAKAN', 'year': 2024, 'stat': 'alert', 'area_ha': 4.488004135131836}, {'code': 19, 'name': 'BOENG TONLE CHHMAR', 'year': 2024, 'stat': 'alert', 'area_ha': 0.6687664001464844}, {'code': 28, 'name': 'KOH KAPI', 'year': 2024, 'stat': 'alert', 'area_ha': 35.76955500934377}, {'code': 59, 'name': 'PREK TOAL', 'year': 2024, 'stat': 'alert', 'area_ha': 1.6458728637695312}, {'code': 60, 'name': 'STUNG TRENG', 'year': 2024, 'stat': 'alert', 'area_ha': 11.255139984576655}, {'code': 65, 'name': 'STUNG SEN', 'year': 2024, 'stat': 'alert', 'area_ha': 3.3564194480895995}, {'code': 4, 'name': 'PHNOM TNOUT-PHNOM POK', 'year': 2024, 'stat': 'alert', 'area_ha': 124.05279753901763}, {'code': 6, 'name': 'PREAEK PRASAP', 'year': 2024, 'stat': 'alert', 'area_ha': 26.771193678244796}, {'code': 7, 'name': 'PREY LANG', 'year': 2024, 'stat': 'alert', 'area_ha': 2779.7467467777597}, {'code': 10, 'name': 'SAM ...
# Data written to sarfdas_alert_protected_areas.csv

# %%
# Define the years to export
years = list(range(2000, 2023 + 1))

# Load the Cambodia boundary
cambodia_boundary = ee.FeatureCollection('projects/earthengine-legacy/assets/projects/servir-mekong/Cambodia-Dashboard-tool/boundaries/cambodia_prvince_odc')

# Function to generate the forest layer and export it
def export_forest_layer(year):
    # Load the images for the given year
    image_tcc = ee.Image(f'projects/servir-mekong/UMD/TCC_C02/{year}')
    image_tch = ee.Image(f'projects/servir-mekong/UMD/TCH_C02/{year}')

    # Create the forest layer
    forest_layer = image_tcc.select('b1').gt(10).And(image_tch.select('b1').gt(5))

    # Clip the forest layer to the Cambodia boundary
    forest_layer_clipped = forest_layer.clip(cambodia_boundary)

    # Get the region in the correct format
    region = cambodia_boundary.geometry().bounds().getInfo()['coordinates']

    # Define the export task
    task = ee.batch.Export.image.toDrive(
        image=forest_layer_clipped,
        description=f'ForestLayer_{year}',
        folder='EarthEngineExports2',  # The folder in Google Drive to export to
        fileNamePrefix=f'ForestLayer_{year}',
        region=region,
        scale=30,  # Adjust the scale if necessary
        maxPixels=1e13,
        crs='EPSG:4326'  # Ensure the exported image is in the desired coordinate reference system
    )

    # Start the export task
    task.start()

# Loop over each year and export the forest layer
for year in years:
    export_forest_layer(year)

print("Export tasks for all available years have been started.")
# Out:
# Export tasks for all available years have been started.
